# %%
import pandas as pd

file = "cities.csv"
df = pd.read_csv(file)

# %%
df = df.set_index("City_ID", drop=True)

# %%
df.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# City_ID
# 0        ostrovnoy           2      RU  1558378754        72  68.05   39.51
# 1        mahebourg          75      MU  1558378503        74 -20.41   57.70
# 2          qaanaaq          25      GL  1558378755        73  77.48  -69.36
# 3           zhuhai           0      CN  1558378755        39  40.71  112.04
# 4        cape town          20      ZA  1558378755        76 -33.93   18.42
#
#          Max Temp  Wind Speed
# City_ID
# 0           37.50        7.16
# 1           78.80       11.41
# 2           22.20        2.37
# 3           44.60        4.47
# 4           55.99        8.05

# %%
from IPython.display import HTML
HTML(df.to_html(classes = 'table table-stripped'))
# Out:
# <table border="1" class="dataframe table table-stripped">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#     <tr>
#       <th>City_ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ostrovnoy</td>
#       <td>2</td>
#       <td>RU</td>
#       <td>1558378754</td>
#       <td>72</td>
#       <td>68.05</td>
#       <td>39.51</td>
#       <td>37.50</td>
#       <td>7.16</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>mahebourg</td>
#       <td>75</td>
#       <td>MU</td>
#       <td>1558378503</td>
#       <td>74</td>
# ...

# %%
html1 = df.to_html(classes = 'table table-stripped').replace("\n","")
html2 = html1.replace("<tr>", "<tr class=\"table-primary\">")
html1
# Out:
# '<table border="1" class="dataframe table table-stripped">  <thead>    <tr style="text-align: right;">      <th></th>      <th>City</th>      <th>Cloudiness</th>      <th>Country</th>      <th>Date</th>      <th>Humidity</th>      <th>Lat</th>      <th>Lng</th>      <th>Max Temp</th>      <th>Wind Speed</th>    </tr>    <tr>      <th>City_ID</th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>ostrovnoy</td>      <td>2</td>      <td>RU</td>      <td>1558378754</td>      <td>72</td>      <td>68.05</td>      <td>39.51</td>      <td>37.50</td>      <td>7.16</td>    </tr>    <tr>      <th>1</th>      <td>mahebourg</td>      <td>75</td>      <td>MU</td>      <td>1558378503</td>      <td>74</td>      <td>-20.41</td>      <td>57.70</td>      <td>78.80</td>      <td>11.41</td>    </tr>    <tr>      <th>2</th>      <td>qaanaaq</td>      <td>25</td
# ...
